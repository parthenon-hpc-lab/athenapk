# %%
import yt
ds = yt.load("./well-balanced/parthenon.prim.00001.phdf")
ad = ds.all_data()
# Out:
# yt : [WARNING  ] 2023-04-25 13:56:53,315 Plasma composition could not be determined in data file. Falling back to fully ionized primodial composition.
# yt : [INFO     ] 2023-04-25 13:56:53,335 Parameters: current_time              = 100.32131607380698
# yt : [INFO     ] 2023-04-25 13:56:53,336 Parameters: domain_dimensions         = [ 64  64 128]
# yt : [INFO     ] 2023-04-25 13:56:53,336 Parameters: domain_left_edge          = [ -50.  -50. -100.]
# yt : [INFO     ] 2023-04-25 13:56:53,337 Parameters: domain_right_edge         = [ 50.  50. 100.]
# yt : [INFO     ] 2023-04-25 13:56:53,337 Parameters: cosmological_simulation   = 0

# %%
p1 = yt.create_profile(ad, "z", ["grav_accel_z"], weight_field=None)
plot = p1.plot()
plot.set_log(field="grav_accel_z", log=False)
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
p1 = yt.create_profile(ad, "z", ["drho_over_rho"], weight_field=None)
plot = p1.plot()
plot.set_log(field="drho_over_rho", log=False)
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
