# %%
import yt

# %%
ds = yt.load("./parthenon.prim.final.phdf")
# Out:
# yt : [WARNING  ] 2023-01-25 17:25:47,220 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2023-01-25 17:25:47,241 Parameters: current_time              = 100.0
# yt : [INFO     ] 2023-01-25 17:25:47,244 Parameters: domain_dimensions         = [ 64  64 128]
# yt : [INFO     ] 2023-01-25 17:25:47,248 Parameters: domain_left_edge          = [ -50.  -50. -100.]
# yt : [INFO     ] 2023-01-25 17:25:47,250 Parameters: domain_right_edge         = [ 50.  50. 100.]
# yt : [INFO     ] 2023-01-25 17:25:47,251 Parameters: cosmological_simulation   = 0.0

# %%
dens = yt.AxisAlignedSlicePlot(ds, normal='x', fields=('parthenon', 'Density')).set_figure_size(4)
dens
# Out:
# yt : [INFO     ] 2023-01-25 17:25:47,460 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-25 17:25:47,460 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-01-25 17:25:47,461 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-25 17:25:47,461 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-01-25 17:25:47,463 Making a fixed resolution buffer of (('parthenon', 'Density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
slice = yt.AxisAlignedSlicePlot(ds, normal='x', fields=('parthenon', 'Velocity3')).set_figure_size(4)
#slice.save()
slice
# Out:
# yt : [INFO     ] 2023-01-25 17:25:47,815 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-25 17:25:47,816 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-01-25 17:25:47,816 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-25 17:25:47,816 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-01-25 17:25:47,818 Making a fixed resolution buffer of (('parthenon', 'Velocity3')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
slice = yt.AxisAlignedSlicePlot(ds, normal='x', fields=('gas', 'temperature')).set_figure_size(4)
#slice.save()
slice
# Out:
# yt : [INFO     ] 2023-01-25 17:25:48,240 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-25 17:25:48,240 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-01-25 17:25:48,241 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-25 17:25:48,241 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-01-25 17:25:48,243 Making a fixed resolution buffer of (('gas', 'temperature')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
