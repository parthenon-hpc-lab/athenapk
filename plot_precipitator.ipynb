# %%
import yt

# %%
ds = yt.load("./parthenon.prim.final.phdf")
# Out:
# yt : [WARNING  ] 2023-01-24 16:44:01,775 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2023-01-24 16:44:01,795 Parameters: current_time              = 960.0
# yt : [INFO     ] 2023-01-24 16:44:01,796 Parameters: domain_dimensions         = [128 128 256]
# yt : [INFO     ] 2023-01-24 16:44:01,797 Parameters: domain_left_edge          = [ -50.  -50. -100.]
# yt : [INFO     ] 2023-01-24 16:44:01,798 Parameters: domain_right_edge         = [ 50.  50. 100.]
# yt : [INFO     ] 2023-01-24 16:44:01,798 Parameters: cosmological_simulation   = 0.0

# %%
dens = yt.AxisAlignedSlicePlot(ds, normal='x', fields=('parthenon', 'Density')).set_figure_size(4)
dens
# Out:
# yt : [INFO     ] 2023-01-24 16:44:02,003 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-24 16:44:02,003 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-01-24 16:44:02,004 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-24 16:44:02,004 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-01-24 16:44:02,006 Making a fixed resolution buffer of (('parthenon', 'Density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
slice = yt.AxisAlignedSlicePlot(ds, normal='x', fields=('parthenon', 'Velocity3')).set_figure_size(4)
#slice.save()
slice
# Out:
# yt : [INFO     ] 2023-01-24 16:44:02,386 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-24 16:44:02,386 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-01-24 16:44:02,387 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-24 16:44:02,387 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-01-24 16:44:02,388 Making a fixed resolution buffer of (('parthenon', 'Velocity3')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
slice = yt.AxisAlignedSlicePlot(ds, normal='x', fields=('gas', 'temperature')).set_figure_size(4)
#slice.save()
slice
# Out:
# yt : [INFO     ] 2023-01-24 16:44:03,045 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-24 16:44:03,046 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-01-24 16:44:03,046 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-24 16:44:03,047 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-01-24 16:44:03,048 Making a fixed resolution buffer of (('gas', 'temperature')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
