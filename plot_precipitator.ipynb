# %%
import yt
ds = yt.load("./tcool_tff_0.1/parthenon.prim.00000.phdf")
# Out:
# yt : [WARNING  ] 2023-02-02 14:53:38,953 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2023-02-02 14:53:38,974 Parameters: current_time              = 0.0
# yt : [INFO     ] 2023-02-02 14:53:38,975 Parameters: domain_dimensions         = [ 64  64 128]
# yt : [INFO     ] 2023-02-02 14:53:38,976 Parameters: domain_left_edge          = [ -50.  -50. -100.]
# yt : [INFO     ] 2023-02-02 14:53:38,977 Parameters: domain_right_edge         = [ 50.  50. 100.]
# yt : [INFO     ] 2023-02-02 14:53:38,977 Parameters: cosmological_simulation   = 0.0

# %%
dens = yt.AxisAlignedSlicePlot(ds, normal='x', fields=('parthenon', 'Density')).set_figure_size(5)
dens
# Out:
# yt : [INFO     ] 2023-02-02 14:53:39,162 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-02-02 14:53:39,162 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-02-02 14:53:39,163 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-02-02 14:53:39,163 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-02-02 14:53:39,165 Making a fixed resolution buffer of (('parthenon', 'Density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
slice = yt.AxisAlignedSlicePlot(ds, normal='x', fields=('gas', 'temperature')).set_figure_size(5)
#slice.save()
slice
# Out:
# yt : [INFO     ] 2023-02-02 14:53:39,554 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-02-02 14:53:39,555 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-02-02 14:53:39,555 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-02-02 14:53:39,555 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-02-02 14:53:39,557 Making a fixed resolution buffer of (('gas', 'temperature')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
