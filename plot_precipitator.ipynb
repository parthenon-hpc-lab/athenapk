# %%
import yt

# %%
ds = yt.load("./parthenon.prim.final.phdf")
# Out:
# yt : [WARNING  ] 2023-01-24 13:50:38,877 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2023-01-24 13:50:38,896 Parameters: current_time              = 60.0
# yt : [INFO     ] 2023-01-24 13:50:38,897 Parameters: domain_dimensions         = [128 128 256]
# yt : [INFO     ] 2023-01-24 13:50:38,898 Parameters: domain_left_edge          = [ -50.  -50. -100.]
# yt : [INFO     ] 2023-01-24 13:50:38,898 Parameters: domain_right_edge         = [ 50.  50. 100.]
# yt : [INFO     ] 2023-01-24 13:50:38,899 Parameters: cosmological_simulation   = 0.0

# %%
dens = yt.AxisAlignedSlicePlot(ds, normal='x', fields=('parthenon', 'Density')).set_figure_size(4)
dens
# Out:
# yt : [INFO     ] 2023-01-24 13:50:39,091 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-24 13:50:39,091 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-01-24 13:50:39,092 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-24 13:50:39,092 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-01-24 13:50:39,095 Making a fixed resolution buffer of (('parthenon', 'Density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
slice = yt.AxisAlignedSlicePlot(ds, normal='x', fields=('parthenon', 'Velocity3')).set_figure_size(4)
slice.save()
slice
# Out:
# yt : [INFO     ] 2023-01-24 13:50:39,459 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-24 13:50:39,460 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-01-24 13:50:39,460 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-24 13:50:39,460 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-01-24 13:50:39,462 Making a fixed resolution buffer of (('parthenon', 'Velocity3')) 800 by 800
# yt : [INFO     ] 2023-01-24 13:50:39,769 Saving plot parthenon.prim.final_Slice_x_Velocity3.png
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
slice = yt.AxisAlignedSlicePlot(ds, normal='x', fields=('gas', 'temperature')).set_figure_size(4)
slice.save()
slice
# Out:
# yt : [INFO     ] 2023-01-24 13:50:40,024 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-24 13:50:40,025 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-01-24 13:50:40,025 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-24 13:50:40,025 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-01-24 13:50:40,027 Making a fixed resolution buffer of (('gas', 'temperature')) 800 by 800
# yt : [INFO     ] 2023-01-24 13:50:40,223 Saving plot parthenon.prim.final_Slice_x_temperature.png
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
