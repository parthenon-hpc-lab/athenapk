# %%
import yt
ds = yt.load("./parthenon.prim.00003.phdf")
# Out:
# yt : [WARNING  ] 2023-02-02 14:39:06,573 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2023-02-02 14:39:06,598 Parameters: current_time              = 4639.200443134635
# yt : [INFO     ] 2023-02-02 14:39:06,599 Parameters: domain_dimensions         = [ 64  64 128]
# yt : [INFO     ] 2023-02-02 14:39:06,600 Parameters: domain_left_edge          = [ -50.  -50. -100.]
# yt : [INFO     ] 2023-02-02 14:39:06,601 Parameters: domain_right_edge         = [ 50.  50. 100.]
# yt : [INFO     ] 2023-02-02 14:39:06,601 Parameters: cosmological_simulation   = 0.0

# %%
dens = yt.AxisAlignedSlicePlot(ds, normal='x', fields=('parthenon', 'Density')).set_figure_size(5)
dens
# Out:
# yt : [INFO     ] 2023-02-02 14:39:06,778 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-02-02 14:39:06,778 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-02-02 14:39:06,779 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-02-02 14:39:06,779 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-02-02 14:39:06,781 Making a fixed resolution buffer of (('parthenon', 'Density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
slice = yt.AxisAlignedSlicePlot(ds, normal='x', fields=('gas', 'temperature')).set_figure_size(5)
#slice.save()
slice
# Out:
# yt : [INFO     ] 2023-02-02 14:39:07,174 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-02-02 14:39:07,175 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-02-02 14:39:07,175 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-02-02 14:39:07,175 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-02-02 14:39:07,177 Making a fixed resolution buffer of (('gas', 'temperature')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
