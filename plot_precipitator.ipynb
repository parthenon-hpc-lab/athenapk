# %%
import yt

# %%
ds = yt.load("./parthenon.prim.final.phdf")
# Out:
# yt : [WARNING  ] 2023-01-23 17:16:54,646 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2023-01-23 17:16:54,665 Parameters: current_time              = 250.0
# yt : [INFO     ] 2023-01-23 17:16:54,666 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2023-01-23 17:16:54,667 Parameters: domain_left_edge          = [-50. -50. -50.]
# yt : [INFO     ] 2023-01-23 17:16:54,668 Parameters: domain_right_edge         = [50. 50. 50.]
# yt : [INFO     ] 2023-01-23 17:16:54,668 Parameters: cosmological_simulation   = 0.0

# %%
dens = yt.AxisAlignedSlicePlot(ds, normal='x', fields=('parthenon', 'Density'))
dens.set_figure_size(4)
# Out:
# yt : [INFO     ] 2023-01-23 17:16:54,864 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-23 17:16:54,864 ylim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-23 17:16:54,864 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-23 17:16:54,865 ylim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-23 17:16:54,866 Making a fixed resolution buffer of (('parthenon', 'Density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
slice = yt.AxisAlignedSlicePlot(ds, normal='x', fields=('parthenon', 'Velocity3')).set_figure_size(4)
#slice.save()
slice
# Out:
# yt : [INFO     ] 2023-01-23 17:16:55,211 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-23 17:16:55,211 ylim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-23 17:16:55,211 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-23 17:16:55,212 ylim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-23 17:16:55,214 Making a fixed resolution buffer of (('parthenon', 'Velocity3')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
yt.AxisAlignedSlicePlot(ds, normal='x', fields=('gas', 'temperature')).set_figure_size(4)
# Out:
# yt : [INFO     ] 2023-01-23 17:16:55,798 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-23 17:16:55,798 ylim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-23 17:16:55,799 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-23 17:16:55,799 ylim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-23 17:16:55,800 Making a fixed resolution buffer of (('gas', 'temperature')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
