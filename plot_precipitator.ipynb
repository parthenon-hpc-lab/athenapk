# %%
import yt
ds = yt.load("./parthenon.prim.00001.phdf")
# Out:
# yt : [WARNING  ] 2023-02-06 14:48:46,594 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2023-02-06 14:48:46,630 Parameters: current_time              = 1000.6446890768067
# yt : [INFO     ] 2023-02-06 14:48:46,631 Parameters: domain_dimensions         = [128 128 256]
# yt : [INFO     ] 2023-02-06 14:48:46,632 Parameters: domain_left_edge          = [ -50.  -50. -100.]
# yt : [INFO     ] 2023-02-06 14:48:46,632 Parameters: domain_right_edge         = [ 50.  50. 100.]
# yt : [INFO     ] 2023-02-06 14:48:46,633 Parameters: cosmological_simulation   = 0.0

# %%
dens = yt.AxisAlignedSlicePlot(ds, normal='x', fields=('parthenon', 'Density')).set_figure_size(5)
dens
# Out:
# yt : [INFO     ] 2023-02-06 14:48:47,020 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-02-06 14:48:47,021 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-02-06 14:48:47,021 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-02-06 14:48:47,021 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-02-06 14:48:47,024 Making a fixed resolution buffer of (('parthenon', 'Density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
slice = yt.AxisAlignedSlicePlot(ds, normal='x', fields=('gas', 'temperature')).set_figure_size(5)
#slice.save()
slice
# Out:
# yt : [INFO     ] 2023-02-06 14:48:48,066 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-02-06 14:48:48,066 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-02-06 14:48:48,066 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-02-06 14:48:48,066 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-02-06 14:48:48,068 Making a fixed resolution buffer of (('gas', 'temperature')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
