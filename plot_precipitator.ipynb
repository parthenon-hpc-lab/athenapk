# %%
import yt

# %%
ds = yt.load("./parthenon.prim.final.phdf")
# Out:
# yt : [WARNING  ] 2023-01-30 23:53:28,489 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2023-01-30 23:53:28,512 Parameters: current_time              = 5000.0
# yt : [INFO     ] 2023-01-30 23:53:28,513 Parameters: domain_dimensions         = [ 64  64 128]
# yt : [INFO     ] 2023-01-30 23:53:28,514 Parameters: domain_left_edge          = [ -50.  -50. -100.]
# yt : [INFO     ] 2023-01-30 23:53:28,515 Parameters: domain_right_edge         = [ 50.  50. 100.]
# yt : [INFO     ] 2023-01-30 23:53:28,515 Parameters: cosmological_simulation   = 0.0

# %%
dens = yt.AxisAlignedSlicePlot(ds, normal='x', fields=('parthenon', 'Density')).set_figure_size(4)
dens
# Out:
# yt : [INFO     ] 2023-01-30 23:53:28,700 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-30 23:53:28,700 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-01-30 23:53:28,701 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-30 23:53:28,701 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-01-30 23:53:28,703 Making a fixed resolution buffer of (('parthenon', 'Density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
slice = yt.AxisAlignedSlicePlot(ds, normal='x', fields=('parthenon', 'Velocity3')).set_figure_size(4)
#slice.save()
slice
# Out:
# yt : [INFO     ] 2023-01-30 23:53:29,136 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-30 23:53:29,136 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-01-30 23:53:29,137 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-30 23:53:29,137 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-01-30 23:53:29,138 Making a fixed resolution buffer of (('parthenon', 'Velocity3')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
slice = yt.AxisAlignedSlicePlot(ds, normal='x', fields=('gas', 'temperature')).set_figure_size(4)
#slice.save()
slice
# Out:
# yt : [INFO     ] 2023-01-30 23:53:29,634 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-30 23:53:29,634 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-01-30 23:53:29,635 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-30 23:53:29,635 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-01-30 23:53:29,636 Making a fixed resolution buffer of (('gas', 'temperature')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
