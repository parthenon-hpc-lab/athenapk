# %%
import yt
ds = yt.load("./parthenon.prim.final.phdf")
# Out:
# yt : [WARNING  ] 2023-02-01 14:50:59,726 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2023-02-01 14:50:59,759 Parameters: current_time              = 10000.0
# yt : [INFO     ] 2023-02-01 14:50:59,759 Parameters: domain_dimensions         = [ 64  64 128]
# yt : [INFO     ] 2023-02-01 14:50:59,760 Parameters: domain_left_edge          = [ -50.  -50. -100.]
# yt : [INFO     ] 2023-02-01 14:50:59,761 Parameters: domain_right_edge         = [ 50.  50. 100.]
# yt : [INFO     ] 2023-02-01 14:50:59,761 Parameters: cosmological_simulation   = 0.0

# %%
dens = yt.AxisAlignedSlicePlot(ds, normal='x', fields=('parthenon', 'Density')).set_figure_size(5)
dens
# Out:
# yt : [INFO     ] 2023-02-01 14:51:00,009 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-02-01 14:51:00,009 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-02-01 14:51:00,010 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-02-01 14:51:00,010 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-02-01 14:51:00,013 Making a fixed resolution buffer of (('parthenon', 'Density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
slice = yt.AxisAlignedSlicePlot(ds, normal='x', fields=('gas', 'temperature')).set_figure_size(5)
#slice.save()
slice
# Out:
# yt : [INFO     ] 2023-02-01 14:51:00,651 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-02-01 14:51:00,652 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-02-01 14:51:00,652 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-02-01 14:51:00,652 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-02-01 14:51:00,654 Making a fixed resolution buffer of (('gas', 'temperature')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
