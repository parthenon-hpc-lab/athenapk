# %%
import yt

# %%
ds = yt.load("./parthenon.prim.final.phdf")
# Out:
# yt : [WARNING  ] 2023-01-23 15:10:55,960 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2023-01-23 15:10:55,979 Parameters: current_time              = 250.0
# yt : [INFO     ] 2023-01-23 15:10:55,980 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2023-01-23 15:10:55,981 Parameters: domain_left_edge          = [-50. -50. -50.]
# yt : [INFO     ] 2023-01-23 15:10:55,982 Parameters: domain_right_edge         = [50. 50. 50.]
# yt : [INFO     ] 2023-01-23 15:10:55,982 Parameters: cosmological_simulation   = 0.0

# %%
dens = yt.AxisAlignedSlicePlot(ds, normal='x', fields=('parthenon', 'Density'))
dens.set_figure_size(4)
# Out:
# yt : [INFO     ] 2023-01-23 15:10:56,181 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-23 15:10:56,181 ylim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-23 15:10:56,182 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-23 15:10:56,182 ylim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-23 15:10:56,184 Making a fixed resolution buffer of (('parthenon', 'Density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
slice = yt.AxisAlignedSlicePlot(ds, normal='x', fields=('parthenon', 'Velocity3')).set_figure_size(4)
#slice.save()
slice
# Out:
# yt : [INFO     ] 2023-01-23 15:10:56,523 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-23 15:10:56,523 ylim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-23 15:10:56,524 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-23 15:10:56,524 ylim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-23 15:10:56,526 Making a fixed resolution buffer of (('parthenon', 'Velocity3')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
yt.AxisAlignedSlicePlot(ds, normal='x', fields=('gas', 'temperature')).set_figure_size(4)
# Out:
# yt : [INFO     ] 2023-01-23 15:10:57,002 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-23 15:10:57,003 ylim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-23 15:10:57,003 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-23 15:10:57,003 ylim = -50.000000 50.000000
# yt : [INFO     ] 2023-01-23 15:10:57,004 Making a fixed resolution buffer of (('gas', 'temperature')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
