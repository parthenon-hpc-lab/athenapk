# %%
import yt
ds = yt.load("./parthenon.prim.final.phdf")
# Out:
# yt : [WARNING  ] 2023-02-01 21:08:46,115 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2023-02-01 21:08:46,140 Parameters: current_time              = 10000.0
# yt : [INFO     ] 2023-02-01 21:08:46,140 Parameters: domain_dimensions         = [ 64  64 128]
# yt : [INFO     ] 2023-02-01 21:08:46,142 Parameters: domain_left_edge          = [ -50.  -50. -100.]
# yt : [INFO     ] 2023-02-01 21:08:46,143 Parameters: domain_right_edge         = [ 50.  50. 100.]
# yt : [INFO     ] 2023-02-01 21:08:46,143 Parameters: cosmological_simulation   = 0.0

# %%
dens = yt.AxisAlignedSlicePlot(ds, normal='x', fields=('parthenon', 'Density')).set_figure_size(5)
dens
# Out:
# yt : [INFO     ] 2023-02-01 21:08:46,340 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-02-01 21:08:46,340 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-02-01 21:08:46,341 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-02-01 21:08:46,341 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-02-01 21:08:46,344 Making a fixed resolution buffer of (('parthenon', 'Density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
slice = yt.AxisAlignedSlicePlot(ds, normal='x', fields=('gas', 'temperature')).set_figure_size(5)
#slice.save()
slice
# Out:
# yt : [INFO     ] 2023-02-01 21:08:46,822 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-02-01 21:08:46,822 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-02-01 21:08:46,823 xlim = -50.000000 50.000000
# yt : [INFO     ] 2023-02-01 21:08:46,823 ylim = -100.000000 100.000000
# yt : [INFO     ] 2023-02-01 21:08:46,824 Making a fixed resolution buffer of (('gas', 'temperature')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
